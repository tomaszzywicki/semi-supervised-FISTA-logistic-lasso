# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..')
from pathlib import Path

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from src.utils import load_arff, set_best_st_approach
from src.experiment import run_experiment
from src.visualizations import plot_experiment_results

import warnings

warnings.filterwarnings("ignore")

# %%
RESULTS_PATH = Path("../results").resolve()

# %%
# for experiment
seeds = list(range(10))
approaches = ["naive", "self_training", "label_propagation"]

# for visualizations
metrics_to_plot = ["Accuracy", "Balanced_Acc", "F1", "ROC_AUC"]

k_best = [1]

mar1_w = [1, 3]
mar1_b = [0, 2]
mar2_w = [1, 3]
mar2_b = [0, 2]
mnar_wx = [1, 3]
mnar_wy = [1, 3]
mnar_b = [0, 2]

# %%
lsvt = load_arff("../data/raw/lsvt.arff")

X = lsvt.iloc[:, :-1].to_numpy()
y = lsvt.iloc[:, [-1]].to_numpy().ravel()
y
y = np.where(y == "2", 1, 0).astype(int)

results_lsvt = run_experiment(
    X,
    y,
    mar1_w=mar1_w,
    mar1_b=mar1_b,
    mar2_w=mar2_w,
    mar2_b=mar2_b,
    mnar_wx=mnar_wx,
    mnar_wy=mnar_wy,
    mnar_b=mnar_b,
    seeds=seeds,
    approaches=approaches,
    k_best=k_best,
    verbose=False,
    save_path=RESULTS_PATH / 'lsvt.csv'
)
# Out:
# 2026-04-07 13:40:47,801 [INFO] Experiment for SEED: 0
# 2026-04-07 13:46:08,290 [INFO] Experiment for SEED: 1
# 2026-04-07 13:51:22,512 [INFO] Experiment for SEED: 2
# 2026-04-07 13:57:09,945 [INFO] Experiment for SEED: 3
# 2026-04-07 14:02:20,709 [INFO] Experiment for SEED: 4
# 2026-04-07 14:07:50,845 [INFO] Experiment for SEED: 5
# 2026-04-07 14:13:11,125 [INFO] Experiment for SEED: 6
# 2026-04-07 14:19:16,270 [INFO] Experiment for SEED: 7
# 2026-04-07 14:24:01,275 [INFO] Experiment for SEED: 8
# 2026-04-07 14:28:57,728 [INFO] Experiment for SEED: 9
# 2026-04-07 14:33:38,076 [INFO] Results saved to /home/tomek2/studia/semestr_8/aml/projekty/semi-supervised-FISTA-logistic-lasso/results/lsvt.csv
# 2026-04-07 14:33:38,077 [INFO] End of experiment

# %%
darwin = pd.read_csv("../data/raw/DARWIN.csv")

X = darwin.iloc[:, 1:-1].to_numpy()
y = darwin.iloc[:, -1].to_numpy()
y = np.where(y == "P", 1, 0)

results_darwin = run_experiment(
    X,
    y,
        mar1_w=mar1_w,
    mar1_b=mar1_b,
    mar2_w=mar2_w,
    mar2_b=mar2_b,
    mnar_wx=mnar_wx,
    mnar_wy=mnar_wy,
    mnar_b=mnar_b,
    seeds=seeds,
    approaches=approaches,
    k_best=k_best,
    verbose=False,
    save_path=RESULTS_PATH / 'darwin.csv'
)
# Out:
# 2026-04-07 16:02:32,496 [INFO] Experiment for SEED: 0
# 2026-04-07 16:08:48,410 [INFO] Experiment for SEED: 1
# 2026-04-07 16:14:19,923 [INFO] Experiment for SEED: 2
# 2026-04-07 16:20:23,002 [INFO] Experiment for SEED: 3
# 2026-04-07 16:25:47,610 [INFO] Experiment for SEED: 4
# 2026-04-07 16:31:37,257 [INFO] Experiment for SEED: 5
# 2026-04-07 16:36:54,748 [INFO] Experiment for SEED: 6
# 2026-04-07 16:42:52,208 [INFO] Experiment for SEED: 7
# 2026-04-07 16:48:40,569 [INFO] Experiment for SEED: 8
# 2026-04-07 16:54:46,429 [INFO] Experiment for SEED: 9
# 2026-04-07 17:00:39,752 [INFO] Results saved to /home/tomek2/studia/semestr_8/aml/projekty/semi-supervised-FISTA-logistic-lasso/results/darwin.csv
# 2026-04-07 17:00:39,754 [INFO] End of experiment

# %%
sonar = pd.read_csv('../data/raw/sonar.all-data', header=None)
X = sonar.iloc[:, :-1].to_numpy()
y = sonar.iloc[:, [-1]].to_numpy().ravel()
y = np.where(y == 'R', 0, 1)

results_darwin = run_experiment(
    X,
    y,
    mar1_w=mar1_w,
    mar1_b=mar1_b,
    mar2_w=mar2_w,
    mar2_b=mar2_b,
    mnar_wx=mnar_wx,
    mnar_wy=mnar_wy,
    mnar_b=mnar_b,
    seeds=seeds,
    approaches=approaches,
    k_best=k_best,
    verbose=False,
    save_path=RESULTS_PATH / 'sonar.csv'
)
# Out:
# 2026-04-07 15:03:43,049 [INFO] Experiment for SEED: 0
# 2026-04-07 15:10:38,604 [INFO] Experiment for SEED: 1
# 2026-04-07 15:17:20,032 [INFO] Experiment for SEED: 2
# 2026-04-07 15:24:23,422 [INFO] Experiment for SEED: 3
# 2026-04-07 15:31:51,222 [INFO] Experiment for SEED: 4
# 2026-04-07 15:37:00,393 [INFO] Experiment for SEED: 5
# 2026-04-07 15:41:46,931 [INFO] Experiment for SEED: 6
# 2026-04-07 15:47:04,065 [INFO] Experiment for SEED: 7
# 2026-04-07 15:52:27,869 [INFO] Experiment for SEED: 8
# 2026-04-07 15:57:25,096 [INFO] Experiment for SEED: 9
# 2026-04-07 16:02:32,435 [INFO] Results saved to /home/tomek2/studia/semestr_8/aml/projekty/semi-supervised-FISTA-logistic-lasso/results/sonar.csv
# 2026-04-07 16:02:32,436 [INFO] End of experiment

# %% [markdown]
# ### prostate

# %%
prostate = pd.read_csv("../data/raw/prostmat.csv", header=None).T

prostate_X = prostate.iloc[:, 1:].to_numpy()
prostate_y = prostate.iloc[:, 0].to_numpy()
prostate_y = np.where(prostate_y == "cancer", 1, 0).astype(int)

seeds = list(range(40))
results_prostate = run_experiment(
    prostate_X,
    prostate_y,
    mar1_w=mar1_w,
    mar1_b=mar1_b,
    mar2_w=mar2_w,
    mar2_b=mar2_b,
    mnar_wx=mnar_wx,
    mnar_wy=mnar_wy,
    mnar_b=mnar_b,
    seeds=seeds,
    approaches=approaches,
    k_best=k_best,
    verbose=False,
    save_path=RESULTS_PATH / 'prostate.csv'
)
# Out:
# 2026-04-07 18:56:23,397 [INFO] Experiment for SEED: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 8
#       5 prostate_y = np.where(prostate_y == "cancer", 1, 0).astype(int)
#       7 seeds = list(range(40))
# ----> 8 results_prostate = run_experiment(
#       9     prostate_X,
#      10     prostate_y,
#      11         mar1_w=mar1_w,
#      12     mar1_b=mar1_b,
#      13     mar2_w=mar2_w,
#      14     mar2_b=mar2_b,
#      15     mnar_wx=mnar_wx,
#      16     mnar_wy=mnar_wy,
#      17     mnar_b=mnar_b,
#      18     seeds=seeds,
#      19     approaches=approaches,
#      20     k_best=k_best,
#      21     verbose=False,
#      22     save_path=RESULTS_PATH / 'prostate.csv'
#      23 )
#
# File ~/studia/semestr_8/aml/projekty/semi-supervised-FISTA-logistic-lasso/notebooks/../src/experiment.py:93, in run_experiment(X, y, mar1_w, mar1_b, mar2_w, mar2_b, mnar_wx, mnar_wy, mnar_b, seeds, approaches, k_best, verbose, save_path)
#      86 X_temp, X_test, y_temp, y_test = train_test_split(X, y, test_size=0.2, random_state=seed, stratify=y)
#      88 X_train, X_val, y_train, y_val = train_test_split(
#      89     X_temp, y_temp, test_size=0.25, random_state=seed, stratify=y_temp
#      90 )
#      92 pipeline = Pipeline(
# ---> 93     [
#      94         ("imputer", SimpleImputer(strategy="median")),
#      95         ("scaler", StandardScaler()),
#      96         ("selector", ColumnSelector(threshold=0.7)),
#      97     ]
#      98 )
#     100 X_train = pipeline.fit_transform(X_train, y_train)
#     101 X_val = pipeline.transform(X_val)
#
# File ~/studia/semestr_8/aml/projekty/semi-supervised-FISTA-logistic-lasso/notebooks/../src/unlabeled_lr.py:90, in UnlabeledLogReg.fit(self, X, y_obs, y_true)
#      83 _imputation_methods = {
#      84     "pseudo_labels": self._fit_pseudo_labels,
#      85     "self_training": self._fit_self_training,
#      86     "label_propagation": self._fit_label_propagation,
#      87 }
#      89 if self.y_imputation_method in _imputation_methods:
# ---> 90     _imputation_methods[self.y_imputation_method](X, y_obs, X_complete, y_complete)
#      92 return self
#
# File ~/studia/semestr_8/aml/projekty/semi-supervised-FISTA-logistic-lasso/notebooks/../src/unlabeled_lr.py:165, in UnlabeledLogReg._fit_self_training(self, X, y_obs, X_complete, y_complete)
#     161     missing_indices = np.delete(missing_indices, idx_to_add)
#     163     self._calculate_imputation_performance(y_obs, y_imputed)
# --> 165 self.model.fit(X_train, y_train)
#
# File ~/studia/semestr_8/aml/projekty/semi-supervised-FISTA-logistic-lasso/notebooks/../src/fista.py:72, in LogisticLassoFistaCV.fit(self, X_train, y_train)
#      69 X_train = np.hstack((np.ones((X_train.shape[0], 1)), X_train))  # Intercept addition
#      70 n, p = X_train.shape[0], X_train.shape[1]
# ---> 72 L = (1 / (4 * n)) * np.linalg.norm(X_train.T @ X_train, ord=2)  # Lipschitz constant
#      74 current_beta = np.zeros(p)
#      76 for reg in sorted(self.lambdas, reverse=True):
#
# File ~/studia/semestr_8/aml/projekty/semi-supervised-FISTA-logistic-lasso/.venv/lib/python3.14/site-packages/numpy/linalg/_linalg.py:2822, in norm(x, ord, axis, keepdims)
#    2820     raise ValueError('Duplicate axes given.')
#    2821 if ord == 2:
# -> 2822     ret = _multi_svd_norm(x, row_axis, col_axis, amax, 0)
#    2823 elif ord == -2:
#    2824     ret = _multi_svd_norm(x, row_axis, col_axis, amin)
#
# File ~/studia/semestr_8/aml/projekty/semi-supervised-FISTA-logistic-lasso/.venv/lib/python3.14/site-packages/numpy/linalg/_linalg.py:2590, in _multi_svd_norm(x, row_axis, col_axis, op, initial)
#    2567 """Compute a function of the singular values of the 2-D matrices in `x`.
#    2568
#    2569 This is a private utility function used by `numpy.linalg.norm()`.
#    (...)   2587
#    2588 """
#    2589 y = moveaxis(x, (row_axis, col_axis), (-2, -1))
# -> 2590 result = op(svd(y, compute_uv=False), axis=-1, initial=initial)
#    2591 return result
#
# File ~/studia/semestr_8/aml/projekty/semi-supervised-FISTA-logistic-lasso/.venv/lib/python3.14/site-packages/numpy/linalg/_linalg.py:1851, in svd(a, full_matrices, compute_uv, hermitian)
#    1847 signature = 'D->d' if isComplexType(t) else 'd->d'
#    1848 with errstate(call=_raise_linalgerror_svd_nonconvergence,
#    1849               invalid='call', over='ignore', divide='ignore',
#    1850               under='ignore'):
# -> 1851     s = _umath_linalg.svd(a, signature=signature)
#    1852 s = s.astype(_realType(result_t), copy=False)
#    1853 return s
#
# KeyboardInterrupt:
