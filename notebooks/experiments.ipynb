# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..')
from pathlib import Path

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from src.utils import load_arff, set_best_st_approach
from src.experiment import run_experiment, run_label_propagation_experiment
from src.visualizations import plot_experiment_results, plot_sigma_results

import warnings

warnings.filterwarnings("ignore")

# %%
RESULTS_PATH = Path("../results").resolve()
RESULTS_PATH_LP = Path("../results/label_propagation").resolve()

# %%
# for experiment
seeds = list(range(10))
sigma_values = [0.1, 0.3, 0.5, 1.0, 1.5, 2.0, 5.0, 10.0, 15.0, 20.0, 30.0, 40.0]
approaches = ["naive", "self_training", "label_propagation"]

# for visualizations
metrics_to_plot = ["Accuracy", "Balanced_Acc", "F1", "ROC_AUC"]

k_best = [1]

mar1_w = [1, 3]
mar1_b = [0, 2]
mar2_w = [1, 3]
mar2_b = [0, 2]
mnar_wx = [1, 3]
mnar_wy = [1, 3]
mnar_b = [0, 2]

# %%
lsvt = load_arff("../data/raw/lsvt.arff")

X = lsvt.iloc[:, :-1].to_numpy()
y = lsvt.iloc[:, [-1]].to_numpy().ravel()
y
y = np.where(y == "2", 1, 0).astype(int)

results_lsvt = run_experiment(
    X,
    y,
    mar1_w=mar1_w,
    mar1_b=mar1_b,
    mar2_w=mar2_w,
    mar2_b=mar2_b,
    mnar_wx=mnar_wx,
    mnar_wy=mnar_wy,
    mnar_b=mnar_b,
    seeds=seeds,
    approaches=approaches,
    k_best=k_best,
    verbose=False,
    save_path=RESULTS_PATH / 'lsvt.csv'
)
# Out:
# 2026-04-07 13:40:47,801 [INFO] Experiment for SEED: 0
# 2026-04-07 13:46:08,290 [INFO] Experiment for SEED: 1
# 2026-04-07 13:51:22,512 [INFO] Experiment for SEED: 2
# 2026-04-07 13:57:09,945 [INFO] Experiment for SEED: 3
# 2026-04-07 14:02:20,709 [INFO] Experiment for SEED: 4
# 2026-04-07 14:07:50,845 [INFO] Experiment for SEED: 5
# 2026-04-07 14:13:11,125 [INFO] Experiment for SEED: 6
# 2026-04-07 14:19:16,270 [INFO] Experiment for SEED: 7
# 2026-04-07 14:24:01,275 [INFO] Experiment for SEED: 8
# 2026-04-07 14:28:57,728 [INFO] Experiment for SEED: 9
# 2026-04-07 14:33:38,076 [INFO] Results saved to /home/tomek2/studia/semestr_8/aml/projekty/semi-supervised-FISTA-logistic-lasso/results/lsvt.csv
# 2026-04-07 14:33:38,077 [INFO] End of experiment

# %%
darwin = pd.read_csv("../data/raw/DARWIN.csv")

X = darwin.iloc[:, 1:-1].to_numpy()
y = darwin.iloc[:, -1].to_numpy()
y = np.where(y == "P", 1, 0)

results_darwin = run_experiment(
    X,
    y,
        mar1_w=mar1_w,
    mar1_b=mar1_b,
    mar2_w=mar2_w,
    mar2_b=mar2_b,
    mnar_wx=mnar_wx,
    mnar_wy=mnar_wy,
    mnar_b=mnar_b,
    seeds=seeds,
    approaches=approaches,
    k_best=k_best,
    verbose=False,
    save_path=RESULTS_PATH / 'darwin.csv'
)
# Out:
# 2026-04-07 16:02:32,496 [INFO] Experiment for SEED: 0
# 2026-04-07 16:08:48,410 [INFO] Experiment for SEED: 1
# 2026-04-07 16:14:19,923 [INFO] Experiment for SEED: 2
# 2026-04-07 16:20:23,002 [INFO] Experiment for SEED: 3
# 2026-04-07 16:25:47,610 [INFO] Experiment for SEED: 4
# 2026-04-07 16:31:37,257 [INFO] Experiment for SEED: 5
# 2026-04-07 16:36:54,748 [INFO] Experiment for SEED: 6
# 2026-04-07 16:42:52,208 [INFO] Experiment for SEED: 7
# 2026-04-07 16:48:40,569 [INFO] Experiment for SEED: 8
# 2026-04-07 16:54:46,429 [INFO] Experiment for SEED: 9
# 2026-04-07 17:00:39,752 [INFO] Results saved to /home/tomek2/studia/semestr_8/aml/projekty/semi-supervised-FISTA-logistic-lasso/results/darwin.csv
# 2026-04-07 17:00:39,754 [INFO] End of experiment

# %%
sonar = pd.read_csv('../data/raw/sonar.all-data', header=None)
X = sonar.iloc[:, :-1].to_numpy()
y = sonar.iloc[:, [-1]].to_numpy().ravel()
y = np.where(y == 'R', 0, 1)

results_darwin = run_experiment(
    X,
    y,
    mar1_w=mar1_w,
    mar1_b=mar1_b,
    mar2_w=mar2_w,
    mar2_b=mar2_b,
    mnar_wx=mnar_wx,
    mnar_wy=mnar_wy,
    mnar_b=mnar_b,
    seeds=seeds,
    approaches=approaches,
    k_best=k_best,
    verbose=False,
    save_path=RESULTS_PATH / 'sonar.csv'
)
# Out:
# 2026-04-07 15:03:43,049 [INFO] Experiment for SEED: 0
# 2026-04-07 15:10:38,604 [INFO] Experiment for SEED: 1
# 2026-04-07 15:17:20,032 [INFO] Experiment for SEED: 2
# 2026-04-07 15:24:23,422 [INFO] Experiment for SEED: 3
# 2026-04-07 15:31:51,222 [INFO] Experiment for SEED: 4
# 2026-04-07 15:37:00,393 [INFO] Experiment for SEED: 5
# 2026-04-07 15:41:46,931 [INFO] Experiment for SEED: 6
# 2026-04-07 15:47:04,065 [INFO] Experiment for SEED: 7
# 2026-04-07 15:52:27,869 [INFO] Experiment for SEED: 8
# 2026-04-07 15:57:25,096 [INFO] Experiment for SEED: 9
# 2026-04-07 16:02:32,435 [INFO] Results saved to /home/tomek2/studia/semestr_8/aml/projekty/semi-supervised-FISTA-logistic-lasso/results/sonar.csv
# 2026-04-07 16:02:32,436 [INFO] End of experiment

# %% [markdown]
# ### prostate

# %%
prostate = pd.read_csv("../data/raw/prostmat.csv", header=None).T

prostate_X = prostate.iloc[:, 1:].to_numpy()
prostate_y = prostate.iloc[:, 0].to_numpy()
prostate_y = np.where(prostate_y == "cancer", 1, 0).astype(int)

seeds = list(range(10))
results_prostate = run_experiment(
    prostate_X,
    prostate_y,
    mar1_w=mar1_w,
    mar1_b=mar1_b,
    mar2_w=mar2_w,
    mar2_b=mar2_b,
    mnar_wx=mnar_wx,
    mnar_wy=mnar_wy,
    mnar_b=mnar_b,
    seeds=seeds,
    approaches=approaches,
    k_best=k_best,
    verbose=False,
    save_path=RESULTS_PATH / 'prostate.csv'
)
# Out:
# 2026-04-09 19:17:25,662 [INFO] Experiment for SEED: 0
# 2026-04-09 21:45:12,542 [INFO] Experiment for SEED: 1
# 2026-04-09 23:22:12,275 [INFO] Experiment for SEED: 2
# 2026-04-10 00:53:22,196 [INFO] Experiment for SEED: 3
# 2026-04-10 02:25:42,339 [INFO] Experiment for SEED: 4
# 2026-04-10 03:58:25,589 [INFO] Experiment for SEED: 5
# 2026-04-10 05:32:09,885 [INFO] Experiment for SEED: 6
# 2026-04-10 07:22:30,645 [INFO] Experiment for SEED: 7
# 2026-04-10 09:46:08,622 [INFO] Experiment for SEED: 8
# 2026-04-10 12:04:14,206 [INFO] Experiment for SEED: 9
# 2026-04-10 13:37:38,862 [INFO] Results saved to /home/tomek/studia/semestr_8_here/aml/projekty/semi-supervised-FISTA-logistic-lasso/results/prostate.csv
# 2026-04-10 13:37:38,863 [INFO] End of experiment

# %% [markdown]
# # label propagation experiemtns

# %%
lsvt = load_arff("../data/raw/lsvt.arff")

X = lsvt.iloc[:, :-1].to_numpy()
y = lsvt.iloc[:, [-1]].to_numpy().ravel()
y
y = np.where(y == "2", 1, 0).astype(int)

results_lsvt = run_label_propagation_experiment(
    X,
    y,
    mar1_w=mar1_w,
    mar1_b=mar1_b,
    mar2_w=mar2_w,
    mar2_b=mar2_b,
    mnar_wx=mnar_wx,
    mnar_wy=mnar_wy,
    mnar_b=mnar_b,
    sigma_vals=sigma_values,
    seeds=seeds,
    save_path=RESULTS_PATH_LP / 'lsvt.csv'
)
# Out:
# 2026-04-08 20:37:27,455 [INFO] Experiment for SEED: 0
# 2026-04-08 20:43:31,638 [INFO] Experiment for SEED: 1
# 2026-04-08 20:46:16,124 [INFO] Experiment for SEED: 2
# 2026-04-08 20:49:12,984 [INFO] Experiment for SEED: 3
# 2026-04-08 20:52:00,452 [INFO] Experiment for SEED: 4
# 2026-04-08 20:54:45,228 [INFO] Experiment for SEED: 5
# 2026-04-08 20:57:29,075 [INFO] Experiment for SEED: 6
# 2026-04-08 21:00:13,860 [INFO] Experiment for SEED: 7
# 2026-04-08 21:03:35,185 [INFO] Experiment for SEED: 8
# 2026-04-08 21:06:27,777 [INFO] Experiment for SEED: 9
# 2026-04-08 21:09:06,582 [INFO] Results saved to C:\Users\macie\OneDrive - Politechnika Warszawska\Pulpit\STUDIA\SEMESTR8\AdvancedML\Projekty\Projekt1\semi-supervised-FISTA-logistic-lasso\results\label_propagation\lsvt.csv
# 2026-04-08 21:09:06,582 [INFO] End of experiment

# %%
darwin = pd.read_csv("../data/raw/DARWIN.csv")

X = darwin.iloc[:, 1:-1].to_numpy()
y = darwin.iloc[:, -1].to_numpy()
y = np.where(y == "P", 1, 0)

results_darwin = run_label_propagation_experiment(
    X,
    y,
    mar1_w=mar1_w,
    mar1_b=mar1_b,
    mar2_w=mar2_w,
    mar2_b=mar2_b,
    mnar_wx=mnar_wx,
    mnar_wy=mnar_wy,
    mnar_b=mnar_b,
    sigma_vals=sigma_values,
    seeds=seeds,
    save_path=RESULTS_PATH_LP / 'darwin.csv'
)
# Out:
# 2026-04-08 21:09:08,151 [INFO] Experiment for SEED: 0
# 2026-04-08 21:12:14,099 [INFO] Experiment for SEED: 1
# 2026-04-08 21:15:22,215 [INFO] Experiment for SEED: 2
# 2026-04-08 21:18:27,186 [INFO] Experiment for SEED: 3
# 2026-04-08 21:21:33,917 [INFO] Experiment for SEED: 4
# 2026-04-08 21:24:37,302 [INFO] Experiment for SEED: 5
# 2026-04-08 21:27:42,847 [INFO] Experiment for SEED: 6
# 2026-04-08 21:30:45,260 [INFO] Experiment for SEED: 7
# 2026-04-08 21:33:49,217 [INFO] Experiment for SEED: 8
# 2026-04-08 21:37:11,746 [INFO] Experiment for SEED: 9
# 2026-04-08 21:40:35,006 [INFO] Results saved to C:\Users\macie\OneDrive - Politechnika Warszawska\Pulpit\STUDIA\SEMESTR8\AdvancedML\Projekty\Projekt1\semi-supervised-FISTA-logistic-lasso\results\label_propagation\darwin.csv
# 2026-04-08 21:40:35,007 [INFO] End of experiment

# %%
prostate = pd.read_csv("../data/raw/prostmat.csv", header=None).T

prostate_X = prostate.iloc[:, 1:].to_numpy()
prostate_y = prostate.iloc[:, 0].to_numpy()
prostate_y = np.where(prostate_y == "cancer", 1, 0).astype(int)

results_prostate = run_label_propagation_experiment(
    prostate_X,
    prostate_y,
    mar1_w=mar1_w,
    mar1_b=mar1_b,
    mar2_w=mar2_w,
    mar2_b=mar2_b,
    mnar_wx=mnar_wx,
    mnar_wy=mnar_wy,
    mnar_b=mnar_b,
    sigma_vals=sigma_values,
    seeds=seeds,
    save_path=RESULTS_PATH_LP / 'prostate.csv'
)
# Out:
# 2026-04-08 21:40:36,273 [INFO] Experiment for SEED: 0

# %%
sonar = pd.read_csv('../data/raw/sonar.all-data', header=None)
X = sonar.iloc[:, :-1].to_numpy()
y = sonar.iloc[:, [-1]].to_numpy().ravel()
y = np.where(y == 'R', 0, 1)

results_sonar = run_label_propagation_experiment(
    X,
    y,
    mar1_w=mar1_w,
    mar1_b=mar1_b,
    mar2_w=mar2_w,
    mar2_b=mar2_b,
    mnar_wx=mnar_wx,
    mnar_wy=mnar_wy,
    mnar_b=mnar_b,
    sigma_vals=sigma_values,
    seeds=seeds,
    save_path=RESULTS_PATH_LP / 'sonar.csv'
)
# Out:
# 2026-04-08 22:03:07,691 [INFO] Experiment for SEED: 0
# 2026-04-08 22:05:43,981 [INFO] Experiment for SEED: 1
# 2026-04-08 22:08:17,774 [INFO] Experiment for SEED: 2
# 2026-04-08 22:11:07,089 [INFO] Experiment for SEED: 3
# 2026-04-08 22:13:49,189 [INFO] Experiment for SEED: 4
# 2026-04-08 22:16:25,506 [INFO] Experiment for SEED: 5
# 2026-04-08 22:19:00,930 [INFO] Experiment for SEED: 6
# 2026-04-08 22:21:40,477 [INFO] Experiment for SEED: 7
# 2026-04-08 22:24:16,381 [INFO] Experiment for SEED: 8
# 2026-04-08 22:26:47,930 [INFO] Experiment for SEED: 9
# 2026-04-08 22:29:32,319 [INFO] Results saved to C:\Users\macie\OneDrive - Politechnika Warszawska\Pulpit\STUDIA\SEMESTR8\AdvancedML\Projekty\Projekt1\semi-supervised-FISTA-logistic-lasso\results\label_propagation\sonar.csv
# 2026-04-08 22:29:32,320 [INFO] End of experiment
